# %%
from ResNet_baseline_final import *
from fastai import *
from fastai.text import *
from nltk.tokenize import word_tokenize
from fastai.callbacks import *
import torch.utils.data as data_utils

# %%
defaults.device = torch.device('cuda')

# %%
PADDING = 64  # 64 for Headlines, 128 for Reddit Main/Pol
DATASET_PATH = '.../Datasets/Headlines/'
DATASET = 'Headlines.csv'
COL = 'headline'   #headline for Headlines, comment for Reddit Main/Pol

# Word embedding weights
WEIGHTS = '.../Datasets/Headlines/Embeddings/glove/Weights_glove_headlines.pkl'

# %%
def pad_to(x:Collection[str], pad_til = PADDING) -> Collection[str]:
    res = []
    count = 0
    for t in x:
        res.append(t)
        count += 1
    while count < pad_til:
        res.append(PAD)
        count +=1
    return res

# %%
tokenizer = Tokenizer(SpacyTokenizer, 'en', pre_rules=[fix_html, replace_rep, replace_wrep, spec_add_spaces, rm_useless_spaces], post_rules=[replace_all_caps, deal_caps, pad_to])

# %%
processor = [TokenizeProcessor(tokenizer=tokenizer), NumericalizeProcessor()]

# %%
data = (TextList.from_csv(DATASET_PATH, DATASET, cols=COL, processor=processor))

# %%
data = data.split_from_df(col='valid').label_from_df(cols=0).databunch()

# %%
weights_matrix = pickle.load(open(WEIGHTS, 'rb'))

# %%
net = ResNet(weights_matrix)

# %%
net.to('cuda')
# Out:
# ResNet(
#   (embedding): Embedding(9120, 50, padding_idx=1)
#   (init_conv): Conv1d(1, 16, kernel_size=(3, 50), stride=(1,), padding=(1, 0), bias=False)
#   (features): Sequential(
#     (init_conv): Conv1d(1, 16, kernel_size=(3, 50), stride=(1,), padding=(1, 0), bias=False)
#     (init_norm): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (init_relu): ReLU(inplace)
#     (resblock1): Sequential(
#       (0): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(16, 16, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Sequential(
#             (0): Conv1d(16, 16, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (2): MergeLayer()
#         )
#       )
#       (1): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(16, 16, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Sequential(
#             (0): Conv1d(16, 16, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (2): MergeLayer()
#         )
#       )
#     )
#     (transition1): SequentialEx(
#       (layers): ModuleList(
#         (0): Conv1d(16, 32, kernel_size=(3,), stride=(2,), padding=(1,), bias=False)
#         (1): dropsampleMergeLayer(
#           (downsample): Conv1d(16, 32, kernel_size=(1,), stride=(2,), bias=False)
#         )
#       )
#     )
#     (resblock2): Sequential(
#       (0): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Sequential(
#             (0): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (2): MergeLayer()
#         )
#       )
#       (1): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Sequential(
#             (0): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (2): MergeLayer()
#         )
#       )
#     )
#     (transition2): SequentialEx(
#       (layers): ModuleList(
#         (0): Conv1d(32, 64, kernel_size=(3,), stride=(2,), padding=(1,), bias=False)
#         (1): dropsampleMergeLayer(
#           (downsample): Conv1d(32, 64, kernel_size=(1,), stride=(2,), bias=False)
#         )
#       )
#     )
#     (resblock3): Sequential(
#       (0): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Sequential(
#             (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (2): MergeLayer()
#         )
#       )
#       (1): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Sequential(
#             (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (2): MergeLayer()
#         )
#       )
#       (2): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Sequential(
#             (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (2): MergeLayer()
#         )
#       )
#       (3): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Sequential(
#             (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (2): MergeLayer()
#         )
#       )
#       (4): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Sequential(
#             (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (2): MergeLayer()
#         )
#       )
#     )
#     (transition3): SequentialEx(
#       (layers): ModuleList(
#         (0): Conv1d(64, 128, kernel_size=(3,), stride=(2,), padding=(1,), bias=False)
#         (1): dropsampleMergeLayer(
#           (downsample): Conv1d(64, 128, kernel_size=(1,), stride=(2,), bias=False)
#         )
#       )
#     )
#     (resblock4): Sequential(
#       (0): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Sequential(
#             (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (2): MergeLayer()
#         )
#       )
#       (1): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Sequential(
#             (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (2): MergeLayer()
#         )
#       )
#       (2): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Sequential(
#             (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (2): MergeLayer()
#         )
#       )
#       (3): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Sequential(
#             (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (2): MergeLayer()
#         )
#       )
#       (4): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Sequential(
#             (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): ReLU(inplace)
#             (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (2): MergeLayer()
#         )
#       )
#     )
#   )
#   (relu): ReLU(inplace)
#   (avgpool): AdaptiveAvgPool1d(output_size=1)
#   (fc1): Linear(in_features=128, out_features=256, bias=True)
#   (classifier): Linear(in_features=256, out_features=2, bias=True)
# )

# %%
learn = Learner(data, net, wd=0.1, loss_func=CrossEntropyFlat(),  metrics=[accuracy, FBeta(average='macro',beta=1),FBeta(average='micro',beta=1)])

# %%
learn.fit_one_cycle(10, 1e-03, moms=(0.8,0.7))
