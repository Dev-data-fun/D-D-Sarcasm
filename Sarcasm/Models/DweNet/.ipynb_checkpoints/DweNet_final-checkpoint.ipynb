# %%
from dweNet_final import *
from fastai import *
from fastai.text import *
from fastai.callbacks import *
from nltk.tokenize import word_tokenize
import torch.utils.data as data_utils
import numpy

# %%
defaults.device = torch.device('cuda')

# %%
PADDING = 64  # 64 for Headlines, 128 for Reddit Main/Pol
DATASET_PATH = '.../Datasets/Headlines/'
DATASET = 'Headlines.csv'
COL = 'headline'   #headline for Headlines, comment for Reddit Main/Pol

# Word embedding weights
WEIGHTS = '.../Datasets/Headlines/Embeddings/glove/Weights_glove_headlines.pkl'

# %%
def pad_to(x:Collection[str], pad_til = PADDING) -> Collection[str]:
    res = []
    count = 0
    for t in x:
        res.append(t)
        count += 1
    while count < pad_til:
        res.append(PAD)
        count +=1
    return res

# %%
tokenizer = Tokenizer(SpacyTokenizer, 'en', pre_rules=[fix_html, replace_rep, replace_wrep, spec_add_spaces, rm_useless_spaces], post_rules=[replace_all_caps, deal_caps, pad_to])

# %%
processor = [TokenizeProcessor(tokenizer=tokenizer), NumericalizeProcessor()]

# %%
data = (TextList.from_csv(DATASET_PATH, DATASET, cols=COL, processor=processor))

# %%
data = data.split_from_df(col='valid').label_from_df(cols=0).databunch()

# %%
weights_matrix = pickle.load(open(WEIGHTS, 'rb'))

# %%
net =  DweNet(weights_matrix)

# %%
net.to('cuda')
# Out:
# DweNet(
#   (embedding): Embedding(9121, 50, padding_idx=1)
#   (features): Sequential(
#     (conv0): Conv1d(1, 64, kernel_size=(3, 50), stride=(1,), padding=(1, 0), bias=False)
#     (norm0): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): LeakyReLU(negative_slope=0.02, inplace)
#     (denseblock1): _DenseBlock(
#       (denselayer1): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(64, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer2): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(96, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer3): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(128, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer4): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(160, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer5): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(192, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer6): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(224, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#     )
#     (transition1): _Transition(
#       (conv): Conv1d(256, 128, kernel_size=(1,), stride=(1,), bias=False)
#       (relu): LeakyReLU(negative_slope=0.02, inplace)
#       (norm): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(128, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer2): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(160, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer3): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(192, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer4): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(224, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer5): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(256, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer6): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(288, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer7): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(320, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer8): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(352, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer9): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(384, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer10): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(416, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer11): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(448, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer12): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(480, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#     )
#     (transition2): _Transition(
#       (conv): Conv1d(512, 256, kernel_size=(1,), stride=(1,), bias=False)
#       (relu): LeakyReLU(negative_slope=0.02, inplace)
#       (norm): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(256, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer2): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(288, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer3): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(320, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer4): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(352, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer5): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(384, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer6): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(416, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer7): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(448, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer8): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(480, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer9): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(512, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer10): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(544, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer11): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(576, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer12): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(608, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer13): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(640, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer14): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(672, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer15): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(704, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer16): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(736, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer17): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(768, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer18): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(800, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer19): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(832, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer20): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(864, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer21): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(896, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer22): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(928, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer23): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(960, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer24): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(992, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#     )
#     (transition3): _Transition(
#       (conv): Conv1d(1024, 512, kernel_size=(1,), stride=(1,), bias=False)
#       (relu): LeakyReLU(negative_slope=0.02, inplace)
#       (norm): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(512, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer2): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(544, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer3): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(576, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer4): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(608, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer5): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(640, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer6): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(672, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer7): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(704, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer8): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(736, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer9): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(768, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer10): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(800, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer11): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(832, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer12): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(864, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer13): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(896, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer14): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(928, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer15): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(960, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#       (denselayer16): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv1d(992, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#             (1): LeakyReLU(negative_slope=0.02, inplace)
#             (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): dropMergeLayer()
#         )
#       )
#     )
#   )
#   (relu): LeakyReLU(negative_slope=0.02, inplace)
#   (fc1): Linear(in_features=2048, out_features=8192, bias=True)
#   (fc2): Linear(in_features=8192, out_features=4096, bias=True)
#   (classifier): Linear(in_features=4096, out_features=2, bias=True)
#   (avgpool): AdaptiveAvgPool1d(output_size=1)
#   (maxpool): AdaptiveMaxPool1d(output_size=1)
# )

# %%
learn = Learner(data, net, wd=0.1, loss_func=CrossEntropyFlat(), metrics=[accuracy, FBeta(average='macro',beta=1),FBeta(average='micro',beta=1)])

# %%
learn.fit_one_cycle(10,1e-03, moms=(0.8,0.7))
